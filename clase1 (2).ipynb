# %%
 import numpy as np #importar un as a np

# %%
x = np.array([2,3])
2*x
# Out:
# array([4, 6])

# %%
np.sin(0)
# Out:
# np.float64(0.0)

# %%
np.sin(np.pi) #para pi necesitas np.pi
# Out:
# np.float64(1.2246467991473532e-16)

# %%
np.sin(np.pi)+1
# Out:
# np.float64(1.0000000000000002)

# %%
np.sin(0.5*np.pi)
# Out:
# np.float64(1.0)

# %%
import math as m

# %%
print(m.sin(0))
print(m.sin(m.pi))
print(m.sin(0.5*m.pi))
# Out:
# 0.0
# 1.2246467991473532e-16
# 1.0

# %%
x = np.linspace(0,np.pi,10)
print(x)
# Out:
# [0.         0.34906585 0.6981317  1.04719755 1.3962634  1.74532925
#  2.0943951  2.44346095 2.7925268  3.14159265]

# %%
x = np.linspace(0,np.pi,10)
print(np.sin(x))
print(m.sin(x))   #no se puede por la biblioteca (no sirve para arreglos)
# Out:
# [0.00000000e+00 3.42020143e-01 6.42787610e-01 8.66025404e-01
#  9.84807753e-01 9.84807753e-01 8.66025404e-01 6.42787610e-01
#  3.42020143e-01 1.22464680e-16]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 x = np.linspace(0,np.pi,10)
#       2 print(np.sin(x))
# ----> 3 print(m.sin(x))
#
# TypeError: only length-1 arrays can be converted to Python scalars

# %%
print(np.sin(1e3*np.pi))
# Out:
# -3.2141664592756335e-13

# %%
print(np.sin(1e6*np.pi))
# Out:
# -2.231912181360871e-10

# %%
print(np.sin(1e6*np.pi))
print(m.sin(1e6*m.pi))
# Out:
# -2.231912181360871e-10
# -2.231912181360871e-10

# %%
6%2.5  # modulo
# Out:
# 1.0

# %%
6%np.pi
# Out:
# 2.858407346410207

# %%
print(np.sin(1e6*np.pi%(2*np.pi)))
print(np.sin(1e6*np.pi))
# Out:
# -1.0072678315071163e-10
# -2.231912181360871e-10

# %%
import mpmath as mp

# %%
mp.pi
# Out:
# <pi: 3.14159~>

# %%
mp.dps = 1e50
mp.sin(1e6*mp.pi)
# Out:
# mpf('-2.2319121813608711e-10')
